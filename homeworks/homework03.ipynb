# %% [markdown]
# # Homework 3
#
# Visualizing relationships between variables
#
# Allen Downey
#
# [MIT License](https://en.wikipedia.org/wiki/MIT_License)

# %%
# %matplotlib inline

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='white')

from utils import decorate
from thinkstats2 import Pmf, Cdf

import thinkstats2
import thinkplot

# %% [markdown]
# ## Loading

# %%
# %time brfss = pd.read_hdf('brfss.hdf5', 'brfss')
# Out:
# CPU times: user 125 ms, sys: 20.3 ms, total: 145 ms
# Wall time: 205 ms

# %%
brfss.shape
# Out:
# (100000, 9)

# %%
brfss.head()
# Out:
#         SEX   HTM4   WTKG3  INCOME2       _LLCPWT  _AGEG5YR  _VEGESU1  \
# 96230   2.0  160.0   60.33      8.0   1398.525290       6.0      2.14
# 244920  2.0  163.0   58.97      5.0     84.057503      13.0      3.14
# 57312   2.0  163.0   72.57      8.0    390.248599       5.0      2.64
# 32573   2.0  165.0   74.84      1.0  11566.705300       3.0      1.46
# 355929  2.0  170.0  108.86      3.0    844.485450       3.0      1.81
#
#         _HTMG10   AGE
# 96230     150.0  47.0
# 244920    160.0  89.5
# 57312     160.0  42.0
# 32573     160.0  32.0
# 355929    160.0  32.0

# %%
brfss.describe()
# Out:
#                 SEX          HTM4         WTKG3       INCOME2        _LLCPWT  \
# count  99938.000000  95143.000000  93404.000000  83447.000000  100000.000000
# mean       1.513809    170.090443     81.202017      5.788656    2785.881001
# std        0.499812     10.795080     20.945679      2.229189    3982.612684
# min        1.000000     91.000000     23.130000      1.000000       5.774036
# 25%        1.000000    163.000000     66.220000      4.000000     579.932564
# 50%        2.000000    170.000000     78.930000      6.000000    1378.138470
# 75%        2.000000    178.000000     90.720000      8.000000    3202.380370
# max        2.000000    226.000000    272.610000      8.000000   45053.592700
#
#            _AGEG5YR      _VEGESU1       _HTMG10           AGE
# count  98794.000000  87713.000000  95143.000000  98794.000000
# mean       6.103296      1.926845    163.915369     47.720732
# std        3.601652      1.290404     11.297379     18.873769
# min        1.000000      0.000000     90.000000     21.000000
# 25%        3.000000      1.140000    160.000000     32.000000
# 50%        6.000000      1.700000    160.000000     47.000000
# 75%        9.000000      2.410000    170.000000     62.000000
# max       13.000000     15.000000    220.000000     89.500000

# %% [markdown]
# ## Scatter plot
#
# Scatter plots are a good way to visualize the relationship between two variables, but it is surprising hard to make a good one.
#
# Here's a simple plot of height and weight.

# %%
height = brfss['HTM4']
weight = brfss['WTKG3']

# %%
plt.plot(height, weight, 'o')

plt.xlabel('Height in cm')
plt.ylabel('Weight in kg');

# %% [markdown]
# The center of this plot is saturated, so it is not as dark as it should be, which means the rest of the plot is relatively darker than it should be.  It gives too much visual weight to the outliers and obscures the shape of the relationship.
#
# **Exercise:** Use keywords `alpha` and `markersize` to avoid saturation.

# %%
plt.plot(height, weight, 'o', alpha=0.2, markersize=2)

# %% [markdown]
# With transparency and smaller markers, you will be able to see that height and weight are discretized.
#
# **Exercise:** Use `np.random.normal` to add enough noise to height and weight so the vertical lines in the scatter plot are blurred out.  Create variables named `height_jitter` and `weight_jitter`.

# %%
# Using values from book that indicated height could be off by 1.3 cm and weigt by 0.5 kg
height_jitter = np.random.normal(-1.3, 1.3, len(height)) + height
weight_jitter = np.random.normal(-0.5, 0.5, len(weight)) + weight
plt.plot(height_jitter, weight_jitter, 'o', alpha=0.1, markersize=1)

# %% [markdown]
# ## Linear regression
#
# We can use `scipy.stats` to find the linear least squares fit to weight as a function of height.

# %%
from scipy.stats import linregress

subset = brfss.dropna(subset=['WTKG3', 'HTM4'])
xs = subset['HTM4']
ys = subset['WTKG3']

res = linregress(xs, ys)
res
# Out:
# LinregressResult(slope=0.9192115381848297, intercept=-75.12704250330233, rvalue=0.47420308979024584, pvalue=0.0, stderr=0.005632863769802998)

# %% [markdown]
# The `LinregressResult` object contains the estimated parameters and a few other statistics.
#
# We can use the estimated `slope` and `intercept` to plot the line of best fit.

# %%
# jitter the data
height_jitter = height + np.random.normal(0, 2, size=len(height))
weight_jitter = weight + np.random.normal(0, 2, size=len(weight))

# make the scatter plot
plt.plot(height_jitter, weight_jitter, 'o', markersize=1, alpha=0.02)
plt.axis([140, 200, 0, 160])

# plot the line of best fit
fx = np.array([xs.min(), xs.max()])
fy = res.intercept + res.slope * fx
plt.plot(fx, fy, '-', alpha=0.5)

# label the axes
plt.xlabel('Height in cm')
plt.ylabel('Weight in kg')
plt.axis([140, 200, 0, 160]);

# %% [markdown]
# ## Weight and age
#
# **Exercise:** Make a scatter plot of weight and age.  The variable `AGE` is discretized in 5-year intervals, so you might want to jitter it.
#
# Adjust transparency and marker size to generate the best view of the relationship.

# %%
age = brfss['AGE']
# Age could be off by 2.5 years in either direction, so std is 2.5, while mean is 0 around original age
age_jitter = np.random.normal(0,2.5,len(age)) + age
plt.plot(age_jitter, weight_jitter, 'o', alpha=0.1, markersize=1)
plt.xlabel('Age (Years)')
plt.ylabel('Weight (kg)')
# Out:
# Text(0, 0.5, 'Weight (kg)')

# %% [markdown]
# **Exercise:** Use `linregress` to estimate the slope and intercept of the line of best fit for this data.
#
# Note: as in the previous example, use `dropna` to drop rows that contain NaN for either variable, and use the resulting subset to compute the arguments for `linregress`.

# %%
subset = brfss.dropna(subset=['AGE', 'WTKG3'])
xs = subset['AGE']
ys = subset['WTKG3']

res = linregress(xs, ys)
res
# Out:
# LinregressResult(slope=0.023981159566968724, intercept=80.07977583683224, rvalue=0.021641432889064068, pvalue=4.374327493007566e-11, stderr=0.003638139410742186)

# %% [markdown]
# **Exercise:** Generate a plot that shows the estimated line and a scatter plot of the data.

# %%
# make the scatter plot
plt.plot(age_jitter, weight_jitter, 'o', markersize=1, alpha=0.02)
#plt.axis([140, 200, 0, 160])

# plot the line of best fit
fx = np.array([xs.min(), xs.max()])
fy = res.intercept + res.slope * fx
plt.plot(fx, fy, '-', alpha=0.5)

# label the axes
plt.xlabel('Age in Years')
plt.ylabel('Weight in kg')
#plt.axis([140, 200, 0, 160]);
# Out:
# Text(0, 0.5, 'Weight in kg')

# %% [markdown]
# Seems reasonable that people's weights dont shift that much after they hit adulthood, but I honestly expected a slightly larger positive slope.

# %% [markdown]
# ## Box and violin plots
#
# The Seaborn package, which is usually imported as `sns`, provides two functions used to show the distribution of one variable as a function of another variable.
#
# The following box plot shows the distribution of weight in each age category.  [Read the documentation](https://seaborn.pydata.org/generated/seaborn.boxplot.html) so you know what it means.

# %%
data = brfss.dropna(subset=['AGE', 'WTKG3'])

sns.boxplot(x='AGE', y='WTKG3', data=data, whis=10)

sns.despine(left=True, bottom=True)
plt.xlabel('Age in years')
plt.ylabel('Weight in kg');

# %% [markdown]
# This figure makes the shape of the relationship clearer; average weight increases between ages 20 and 50, and then decreases.
#
# A violin plot is another way to show the same thing.  Again, [read the documentation](https://seaborn.pydata.org/generated/seaborn.violinplot.html) so you know what it means.

# %% [markdown]
# Yup, this makes a lot more sense to me.

# %%
sns.violinplot(x='AGE', y='WTKG3', data=data, inner=None)

sns.despine(left=True, bottom=True)
plt.xlabel('Age in years')
plt.ylabel('Weight in kg');

# %% [markdown]
# **Exercise:** Make a box plot that shows the distribution of weight as a function of income.  The variable `INCOME2` contains income codes with 8 levels.
#
# Use `dropna` to select the rows with valid income and weight information.

# %%
data = brfss.dropna(subset=['INCOME2', 'WTKG3'])

sns.boxplot(x='INCOME2', y='WTKG3', data=data, whis=5)

sns.despine(left=True, bottom=True)
plt.xlabel('Income Bracket')
plt.ylabel('Weight in kg');

# %% [markdown]
# **Exercise:** Make a violin plot with the same variables.

# %%
sns.violinplot(x='INCOME2', y='WTKG3', data=data, inner=None)

sns.despine(left=True, bottom=True)
plt.xlabel('Income Bracket')
plt.ylabel('Weight in kg');

# %% [markdown]
# Assuming I'm reading these right, looks like there is little to no variation in income based on weight, or vice versa.

# %% [markdown]
# ## Plotting percentiles
#
# One more way to show the relationship between two variables is to break one variables into groups and plot percentiles of the other variable across groups.
#
# As a starting place, here's the median weight in each age group.

# %%
grouped = brfss.groupby('AGE')

for name, group in grouped['WTKG3']:
    print(name, group.median())
# Out:
# 21.0 70.31
# 27.0 77.11
# 32.0 79.38
# 37.0 80.74
# 42.0 81.65
# 47.0 81.65
# 52.0 81.65
# 57.0 81.65
# 62.0 81.65
# 67.0 80.74
# 72.0 79.38
# 77.0 77.11
# 89.5 70.08

# %% [markdown]
# To get the other percentiles, we can use a `Cdf`.

# %%
ps = [95, 75, 50, 25, 5]

for name, group in grouped['WTKG3']:
    percentiles = Cdf(group).Percentiles(ps)
    print(name, percentiles)
# Out:
# 21.0 [108.86  83.91  70.31  59.87  49.9 ]
# 27.0 [117.93  90.72  77.11  65.    52.62]
# 32.0 [122.47  92.99  79.38  65.77  54.43]
# 37.0 [122.47  94.35  80.74  68.04  56.25]
# 42.0 [122.47  95.25  81.65  68.04  55.34]
# 47.0 [124.74  97.52  81.65  69.4   55.79]
# 52.0 [123.38  96.62  81.65  68.95  55.79]
# 57.0 [117.93  95.25  81.65  68.49  54.43]
# 62.0 [122.47  95.25  81.65  68.04  54.43]
# 67.0 [117.93  92.99  80.74  68.04  54.43]
# 72.0 [113.4   90.72  79.38  68.04  53.52]
# 77.0 [111.13  89.81  77.11  65.77  52.16]
# 89.5 [99.79 81.65 69.85 59.87 49.44]

# %% [markdown]
# Now I'll collect those results in a list of arrays:

# %%
res = []
for name, group in grouped['WTKG3']:
    percentiles = Cdf(group).Percentiles(ps)
    res.append(percentiles)
    
res
# Out:
# [array([108.86,  83.91,  70.31,  59.87,  49.9 ]),
#  array([117.93,  90.72,  77.11,  65.  ,  52.62]),
#  array([122.47,  92.99,  79.38,  65.77,  54.43]),
#  array([122.47,  94.35,  80.74,  68.04,  56.25]),
#  array([122.47,  95.25,  81.65,  68.04,  55.34]),
#  array([124.74,  97.52,  81.65,  69.4 ,  55.79]),
#  array([123.38,  96.62,  81.65,  68.95,  55.79]),
#  array([117.93,  95.25,  81.65,  68.49,  54.43]),
#  array([122.47,  95.25,  81.65,  68.04,  54.43]),
#  array([117.93,  92.99,  80.74,  68.04,  54.43]),
#  array([113.4 ,  90.72,  79.38,  68.04,  53.52]),
#  array([111.13,  89.81,  77.11,  65.77,  52.16]),
#  array([99.79, 81.65, 69.85, 59.87, 49.44])]

# %% [markdown]
# To get the age groups, we can extract the "keys" from the groupby object.

# %%
xs = grouped.groups.keys()
xs
# Out:
# dict_keys([21.0, 27.0, 32.0, 37.0, 42.0, 47.0, 52.0, 57.0, 62.0, 67.0, 72.0, 77.0, 89.5])

# %% [markdown]
# Now, we want to loop through the columns of the list of arrays; to do that, we want to transpose it.

# %%
rows = np.transpose(res)
rows
# Out:
# array([[108.86, 117.93, 122.47, 122.47, 122.47, 124.74, 123.38, 117.93,
#         122.47, 117.93, 113.4 , 111.13,  99.79],
#        [ 83.91,  90.72,  92.99,  94.35,  95.25,  97.52,  96.62,  95.25,
#          95.25,  92.99,  90.72,  89.81,  81.65],
#        [ 70.31,  77.11,  79.38,  80.74,  81.65,  81.65,  81.65,  81.65,
#          81.65,  80.74,  79.38,  77.11,  69.85],
#        [ 59.87,  65.  ,  65.77,  68.04,  68.04,  69.4 ,  68.95,  68.49,
#          68.04,  68.04,  68.04,  65.77,  59.87],
#        [ 49.9 ,  52.62,  54.43,  56.25,  55.34,  55.79,  55.79,  54.43,
#          54.43,  54.43,  53.52,  52.16,  49.44]])

# %%
for i, qs in enumerate(rows):
    print(i)
    print(qs)
# Out:
# 0
# [108.86 117.93 122.47 122.47 122.47 124.74 123.38 117.93 122.47 117.93
#  113.4  111.13  99.79]
# 1
# [83.91 90.72 92.99 94.35 95.25 97.52 96.62 95.25 95.25 92.99 90.72 89.81
#  81.65]
# 2
# [70.31 77.11 79.38 80.74 81.65 81.65 81.65 81.65 81.65 80.74 79.38 77.11
#  69.85]
# 3
# [59.87 65.   65.77 68.04 68.04 69.4  68.95 68.49 68.04 68.04 68.04 65.77
#  59.87]
# 4
# [49.9  52.62 54.43 56.25 55.34 55.79 55.79 54.43 54.43 54.43 53.52 52.16
#  49.44]

# %% [markdown]
# Now we can plot the percentiles across the groups.

# %%
width = [1,2,5,2,1]

for i, qs in enumerate(rows):
    plt.plot(xs, qs, label=ps[i], linewidth=width[i], color='C4')
    
decorate(xlabel='Age (years)',
         ylabel='Weight (kg)')

# %% [markdown]
# In my opinion, this plot shows the shape of the relationship most clearly.

# %% [markdown]
# ## Discretizing variables
#
# Box plot, violin plots, and percentile line plots don't work as well if the number of groups on the x-axis is too big.  For example, here's a box plot of weight versus height.

# %%
sns.boxplot(x='HTM4', y='WTKG3', data=data, whis=10)

sns.despine(left=True, bottom=True)
plt.xlabel('Height in cm')
plt.ylabel('Weight in kg');

# %% [markdown]
# This would look better and mean more if there were fewer height groups.  We can use `pd.cut` to put people into height groups where each group spans 10 cm.

# %%
bins = np.arange(0, height.max(), 10)
brfss['_HTMG10'] = pd.cut(brfss['HTM4'], bins=bins, labels=bins[:-1]).astype(float)

# %% [markdown]
# Now here's what the plot looks like.

# %%
sns.boxplot(x='_HTMG10', y='WTKG3', data=brfss, whis=10)
plt.xticks(rotation=30)

sns.despine(left=True, bottom=True)
plt.xlabel('Height in cm')
plt.ylabel('Weight in kg');

# %% [markdown]
# **Exercise:** Plot percentiles of weight versus these height groups.

# %%
brfss.dropna(subset=['_HTMG10', 'WTKG3'])
grouped = brfss.groupby('WTKG3')
ps = [95, 50, 5]
grouped

# %%
res = []
for name, group in grouped['_HTMG10']:
    print(len(ps))
    print(Cdf(group))
    #print(group)
    if (Cdf(group) != Cdf([],[])):
        percentiles = Cdf(group).Percentiles(ps)
        res.append(percentiles)
# Out:
# 3
# Cdf([150.], [1.])
# 3
# Cdf([160. 170.], [0.75 1.  ])
# 3
# Cdf([160.], [1.])
# 3
# Cdf([150.], [1.])
# 3
# Cdf([160.], [1.])
# 3
# Cdf([], [])
# 3
# Cdf([140. 160.], [0.5 1. ])
# 3
# Cdf([120. 140. 150. 160. 170.], [0.125 0.375 0.75  0.875 1.   ])
# 3
# Cdf([160.], [1.])
# 3
# Cdf([], [])
# 3
# Cdf([150. 160.], [0.75 1.  ])
# 3
# Cdf([150. 170.], [0.66666667 1.        ])
# 3
# Cdf([150.], [1.])
# 3
# Cdf([150.], [1.])
# 3
# Cdf([140.], [1.])
# 3
# Cdf([140. 150.], [0.5 1. ])
# 3
# Cdf([150.], [1.])
# 3
# Cdf([140. 150. 160. 180.], [0.11111111 0.88888889 0.94444444 1.        ])
# 3
# Cdf([150.], [1.])
# 3
# Cdf([170.], [1.])
# 3
# Cdf([140. 150. 160.], [0.2 0.8 1. ])
# 3
# Cdf([140.], [1.])
# 3
# Cdf([], [])
# 3
# Cdf([140. 150.], [0.25 1.  ])
# 3
# Cdf([130. 140. 150. 160. 170.], [0.0625  0.625   0.78125 0.9375  1.     ])
# 3
# Cdf([140.], [1.])
# 3
# Cdf([140. 150. 160.], [0.33333333 0.83333333 1.        ])
# 3
# Cdf([140. 150. 160.], [0.42857143 0.57142857 1.        ])
# 3
# Cdf([130. 150.], [0.33333333 1.        ])
# 3
# Cdf([140. 150. 160.], [0.125 0.875 1.   ])
# 3
# Cdf([140. 150. 160. 170. 190.], [0.23728814 0.74576271 0.96610169 0.98305085 1.        ])
# 3
# Cdf([150. 160. 170.], [0.66666667 0.83333333 1.        ])
# 3
# Cdf([140. 150. 160.], [0.38461538 0.84615385 1.        ])
# 3
# Cdf([150.], [1.])
# 3
# Cdf([140. 150. 160. 180.], [0.06451613 0.58064516 0.93548387 1.        ])
# 3
# Cdf([140. 150. 160. 170.], [0.1875 0.8125 0.9375 1.    ])
# 3
# Cdf([120. 130. 140. 150. 160. 180.], [0.01020408 0.02040816 0.24489796 0.78571429 0.98979592 1.        ])
# 3
# Cdf([140. 150. 160. 180.], [0.22727273 0.86363636 0.95454545 1.        ])
# 3
# Cdf([140. 150. 160.], [0.08510638 0.82978723 1.        ])
# 3
# Cdf([140. 150. 160.], [0.21428571 0.86904762 1.        ])
# 3
# Cdf([140. 150. 160.], [0.02941176 0.79411765 1.        ])
# 3
# Cdf([140. 160.], [0.16666667 1.        ])
# 3
# Cdf([140. 150. 160. 170. 190.], [0.1202346  0.73607038 0.96774194 0.99706745 1.        ])
# 3
# Cdf([130. 140. 150. 160. 170. 180.], [0.04 0.08 0.56 0.92 0.96 1.  ])
# 3
# Cdf([140. 150. 160.], [0.14457831 0.84337349 1.        ])
# 3
# Cdf([130. 140. 150. 160. 170.], [0.02439024 0.25609756 0.79268293 0.93902439 1.        ])
# 3
# Cdf([150. 170.], [0.5 1. ])
# 3
# Cdf([130. 140. 150. 160. 170.], [0.01428571 0.11428571 0.82857143 0.98571429 1.        ])
# 3
# Cdf([100. 120. 140. 150. 160. 170. 190.], [0.00597015 0.00895522 0.10149254 0.72835821 0.98208955 0.99701493
#  1.        ])
# 3
# Cdf([150.], [1.])
# 3
# Cdf([140. 150. 160. 170.], [0.08955224 0.71641791 0.97014925 1.        ])
# 3
# Cdf([130. 140. 150. 160. 170.], [0.02941176 0.10294118 0.60294118 0.97058824 1.        ])
# 3
# Cdf([100. 140. 150. 160. 170. 180.], [0.01388889 0.14583333 0.70138889 0.97916667 0.98611111 1.        ])
# 3
# Cdf([160.], [1.])
# 3
# Cdf([140. 150. 160. 170.], [0.14814815 0.64814815 0.94444444 1.        ])
# 3
# Cdf([ 90. 120. 130. 140. 150. 160. 170. 180. 190.], [0.00242424 0.00484848 0.00606061 0.08363636 0.70424242 0.95030303
#  0.98909091 0.99878788 1.        ])
# 3
# Cdf([150. 160.], [0.46153846 1.        ])
# 3
# Cdf([140. 150. 160. 170.], [0.07894737 0.68421053 0.89473684 1.        ])
# 3
# Cdf([120. 130. 140. 150. 160. 170. 180.], [0.00462963 0.01388889 0.06481481 0.66203704 0.94907407 0.99537037
#  1.        ])
# 3
# Cdf([], [])
# 3
# Cdf([140. 150. 160. 170.], [0.14516129 0.64516129 0.94354839 1.        ])
# 3
# Cdf([140. 150. 160. 170.], [0.06410256 0.68589744 0.95512821 1.        ])
# 3
# Cdf([160.], [1.])
# 3
# Cdf([120. 130. 140. 150. 160. 170. 180. 190.], [0.00113507 0.00340522 0.06810443 0.61066969 0.94778661 0.99318956
#  0.9954597  1.        ])
# 3
# Cdf([140. 150. 160. 170.], [0.06716418 0.62686567 0.97761194 1.        ])
# 3
# Cdf([], [])
# 3
# Cdf([130. 140. 150. 160. 170.], [0.00666667 0.04666667 0.54666667 0.94666667 1.        ])
# 3
# Cdf([120. 130. 140. 150. 160. 170. 180.], [0.00357143 0.00714286 0.07142857 0.62142857 0.96428571 0.98571429
#  1.        ])
# 3
# Cdf([140. 150. 160. 170. 180.], [0.09473684 0.47368421 0.92631579 0.98947368 1.        ])
# 3
# Cdf([150. 160.], [0.5 1. ])
# 3
# Cdf([100. 120. 130. 140. 150. 160. 170. 180. 190.], [0.00280426 0.00616938 0.00673023 0.03925967 0.51093662 0.91250701
#  0.98597869 0.99775659 1.        ])
# 3
# Cdf([140. 150. 160. 170.], [0.07792208 0.61038961 0.97402597 1.        ])
# 3
# Cdf([110. 150. 160.], [0.13333333 0.66666667 1.        ])
# 3
# Cdf([130. 140. 150. 160. 170. 190.], [0.00515464 0.09278351 0.5        0.93298969 0.99484536 1.        ])
# 3
# Cdf([140. 150. 160. 170.], [0.10285714 0.58285714 0.96       1.        ])
# 3
# Cdf([160.], [1.])
# 3
# Cdf([140. 150. 160. 170.], [0.06190476 0.4952381  0.95714286 1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 190. 200.], [0.02897657 0.42601726 0.89395808 0.98397041 0.9919852  0.99815043
#  1.        ])
# 3
# Cdf([140. 150. 160.], [0.33333333 0.66666667 1.        ])
# 3
# Cdf([140. 150. 160. 170. 180.], [0.03743316 0.42780749 0.90909091 0.98395722 1.        ])
# 3
# Cdf([120. 130. 140. 150. 160. 170. 180.], [0.0045045  0.00900901 0.04504505 0.45045045 0.91441441 0.9954955
#  1.        ])
# 3
# Cdf([160. 170. 190.], [0.4 0.8 1. ])
# 3
# Cdf([100. 130. 140. 150. 160. 170. 180.], [0.00246305 0.00738916 0.05665025 0.48768473 0.90394089 0.99507389
#  1.        ])
# 3
# Cdf([140. 150. 160. 170. 190.], [0.00729927 0.50364964 0.87591241 0.99270073 1.        ])
# 3
# Cdf([120. 130. 140. 150. 160. 170. 180. 190.], [7.72200772e-04 1.93050193e-03 3.16602317e-02 4.14671815e-01
#  8.65637066e-01 9.81467181e-01 9.98841699e-01 1.00000000e+00])
# 3
# Cdf([160. 170.], [0.2 1. ])
# 3
# Cdf([140. 150. 160. 170. 180. 190.], [0.02564103 0.56410256 0.8974359  0.93589744 0.98717949 1.        ])
# 3
# Cdf([130. 140. 150. 160. 170. 180.], [0.00266667 0.07466667 0.38933333 0.86666667 0.96533333 1.        ])
# 3
# Cdf([130. 140. 150. 160. 170.], [0.0625 0.1875 0.4375 0.8125 1.    ])
# 3
# Cdf([130. 140. 150. 160. 170. 180. 190.], [0.01010101 0.06060606 0.44444444 0.86868687 0.98989899 0.99494949
#  1.        ])
# 3
# Cdf([120. 130. 140. 150. 160. 170. 190. 200.], [0.0044843  0.00896861 0.07623318 0.46188341 0.91928251 0.98206278
#  0.9955157  1.        ])
# 3
# Cdf([150. 170.], [0.33333333 1.        ])
# 3
# Cdf([130. 140. 150. 160. 170. 180. 190. 200.], [0.00249252 0.02841476 0.37337986 0.83698903 0.97507478 0.99601196
#  0.9995015  1.        ])
# 3
# Cdf([120. 140. 150. 160. 170. 180.], [0.00966184 0.04347826 0.50241546 0.87439614 0.99516908 1.        ])
# 3
# Cdf([150. 160. 170.], [0.18181818 0.81818182 1.        ])
# 3
# Cdf([140. 150. 160. 170. 180.], [0.00877193 0.35526316 0.89912281 0.98684211 1.        ])
# 3
# Cdf([130. 140. 150. 160. 170. 180.], [0.00452489 0.03167421 0.42081448 0.89366516 0.99773756 1.        ])
# 3
# Cdf([150. 160. 180.], [0.4 0.7 1. ])
# 3
# Cdf([140. 150. 160. 170. 180.], [0.05194805 0.40909091 0.85714286 0.95454545 1.        ])
# 3
# Cdf([100. 120. 130. 140. 150. 160. 170. 180. 190. 200.], [0.00121914 0.00243828 0.00304785 0.02956416 0.33953063 0.8012801
#  0.96891192 0.99542822 0.99969521 1.        ])
# 3
# Cdf([130. 150. 160. 170. 180. 190. 210.], [0.01265823 0.34177215 0.7721519  0.89873418 0.96202532 0.98734177
#  1.        ])
# 3
# Cdf([110. 150. 160. 170. 180.], [0.125 0.375 0.625 0.75  1.   ])
# 3
# Cdf([140. 150. 160. 170. 180.], [0.01780415 0.3768546  0.81008902 0.98219585 1.        ])
# 3
# Cdf([130. 140. 150. 160. 170. 180. 190.], [0.00369004 0.04428044 0.36900369 0.81180812 0.95940959 0.99261993
#  1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 190.], [0.08 0.16 0.36 0.68 0.96 1.  ])
# 3
# Cdf([140. 150. 160. 170. 180.], [0.01169591 0.36842105 0.76608187 0.97076023 1.        ])
# 3
# Cdf([120. 130. 140. 150. 160. 170. 180. 190.], [0.00281822 0.00375763 0.02160639 0.26679192 0.73884453 0.9544387
#  0.99577266 1.        ])
# 3
# Cdf([160. 170.], [0.5 1. ])
# 3
# Cdf([120. 130. 140. 150. 160. 170. 180. 190.], [0.00505051 0.01010101 0.01515152 0.34343434 0.78787879 0.95959596
#  0.97979798 1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 190.], [0.01729107 0.36023055 0.83285303 0.98270893 0.99135447 1.        ])
# 3
# Cdf([160. 170.], [0.14285714 1.        ])
# 3
# Cdf([130. 140. 150. 160. 170. 180.], [0.01182033 0.03782506 0.39007092 0.84397163 0.9787234  1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 190.], [0.10062893 0.51572327 0.82389937 0.97484277 0.99371069 1.        ])
# 3
# Cdf([150. 160.], [0.2 1. ])
# 3
# Cdf([100. 130. 140. 150. 160. 170. 180. 190. 200.], [2.27169468e-04 9.08677874e-04 2.27169468e-02 2.63743753e-01
#  7.01272149e-01 9.51385734e-01 9.95002272e-01 9.99318492e-01
#  1.00000000e+00])
# 3
# Cdf([150. 160. 170. 180.], [0.25396825 0.77777778 0.99206349 1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 200.], [0.01796407 0.2754491  0.70658683 0.96107784 0.99401198 1.        ])
# 3
# Cdf([160. 170.], [0.5 1. ])
# 3
# Cdf([120. 140. 150. 160. 170. 180.], [0.00352113 0.05985915 0.30633803 0.72535211 0.96478873 1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 190.], [0.02083333 0.29513889 0.75347222 0.97916667 0.99652778 1.        ])
# 3
# Cdf([150. 160. 170. 190.], [0.16666667 0.61111111 0.94444444 1.        ])
# 3
# Cdf([100. 130. 140. 150. 160. 170. 180. 190. 200. 210.], [5.16528926e-04 2.06611570e-03 1.60123967e-02 1.89049587e-01
#  6.22933884e-01 9.22004132e-01 9.89152893e-01 9.97933884e-01
#  9.99483471e-01 1.00000000e+00])
# 3
# Cdf([ 90. 120. 140. 150. 160. 170. 180. 190.], [0.00746269 0.01119403 0.03358209 0.31716418 0.78358209 0.97014925
#  0.99626866 1.        ])
# 3
# Cdf([160. 170.], [0.25 1.  ])
# 3
# Cdf([130. 140. 150. 160. 170. 180. 190.], [0.00423729 0.03389831 0.26271186 0.72033898 0.95762712 0.99152542
#  1.        ])
# 3
# Cdf([140. 150. 160. 170. 180.], [0.00966184 0.25362319 0.647343   0.95410628 1.        ])
# 3
# Cdf([160. 170.], [0.81818182 1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 190.], [0.0212766  0.31914894 0.69503546 0.92907801 0.9858156  1.        ])
# 3
# Cdf([130. 140. 150. 160. 170. 180. 190. 200.], [9.44287063e-04 1.18035883e-02 2.32294618e-01 6.40698772e-01
#  9.20915958e-01 9.92681775e-01 9.99527856e-01 1.00000000e+00])
# 3
# Cdf([160.], [1.])
# 3
# Cdf([100. 150. 160. 170. 180.], [0.01020408 0.20408163 0.70408163 0.96938776 1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 190.], [0.04477612 0.26119403 0.61442786 0.93532338 0.99502488 1.        ])
# 3
# Cdf([130. 140. 150. 160. 170. 180.], [0.00398406 0.02390438 0.26294821 0.73306773 0.96812749 1.        ])
# 3
# Cdf([150. 170. 190.], [0.33333333 0.66666667 1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 190.], [0.03030303 0.16017316 0.62770563 0.88311688 0.98268398 1.        ])
# 3
# Cdf([130. 140. 150. 160. 170. 180. 190.], [0.0012959  0.00691145 0.16933045 0.54038877 0.88855292 0.98704104
#  1.        ])
# 3
# Cdf([140. 160. 170. 180.], [0.05 0.55 0.95 1.  ])
# 3
# Cdf([140. 150. 160. 170. 180.], [0.0137931  0.14482759 0.57931034 0.96551724 1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 190.], [0.02734375 0.234375   0.62890625 0.9140625  0.984375   1.        ])
# 3
# Cdf([160. 170. 190.], [0.25 0.5  1.  ])
# 3
# Cdf([140. 150. 160. 170. 180. 190.], [0.02391304 0.19130435 0.61521739 0.91956522 0.98913043 1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 190.], [0.0212766  0.25531915 0.58156028 0.93617021 0.96453901 1.        ])
# 3
# Cdf([150. 170.], [0.4 1. ])
# 3
# Cdf([100. 120. 140. 150. 160. 170. 180. 190. 200.], [2.67594327e-04 1.07037731e-03 1.47176880e-02 1.75006690e-01
#  5.23949692e-01 8.65132459e-01 9.82338774e-01 9.98662028e-01
#  1.00000000e+00])
# 3
# Cdf([150. 160. 170. 180.], [0.23423423 0.59459459 0.87387387 1.        ])
# 3
# Cdf([150. 160. 170. 180.], [0.27272727 0.36363636 0.90909091 1.        ])
# 3
# Cdf([130. 140. 150. 160. 170. 180. 190. 200.], [0.00214592 0.00429185 0.15021459 0.51072961 0.87553648 0.98712446
#  0.99785408 1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 190.], [0.01327434 0.22123894 0.58849558 0.9159292  0.98230088 1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 190.], [0.0112782  0.2406015  0.64285714 0.92857143 0.96992481 1.        ])
# 3
# Cdf([160. 180.], [0.5 1. ])
# 3
# Cdf([100. 130. 140. 150. 160. 170. 180. 190. 200.], [3.72023810e-04 2.23214286e-03 9.67261905e-03 1.19791667e-01
#  4.39732143e-01 8.28869048e-01 9.73214286e-01 9.97395833e-01
#  1.00000000e+00])
# 3
# Cdf([140. 150. 160. 170. 180. 200.], [0.06735751 0.24870466 0.46632124 0.89119171 0.99481865 1.        ])
# 3
# Cdf([ 90. 160. 170. 180.], [0.04166667 0.29166667 0.625      1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 190.], [0.01863354 0.20496894 0.51552795 0.86335404 0.97515528 1.        ])
# 3
# Cdf([120. 140. 150. 160. 170. 180. 190.], [0.00226757 0.01133787 0.17006803 0.51473923 0.88662132 0.99092971
#  1.        ])
# 3
# Cdf([170.], [1.])
# 3
# Cdf([140. 150. 160. 170. 180.], [0.01052632 0.22631579 0.55789474 0.93684211 1.        ])
# 3
# Cdf([100. 120. 130. 140. 150. 160. 170. 180. 190. 200. 210.], [4.25260472e-04 8.50520944e-04 1.48841165e-03 1.44588560e-02
#  1.48203275e-01 4.85647459e-01 8.42015735e-01 9.74271741e-01
#  9.99574740e-01 9.99787370e-01 1.00000000e+00])
# 3
# Cdf([160. 170. 180.], [0.73333333 0.93333333 1.        ])
# 3
# Cdf([140. 150. 160. 170. 180.], [0.00925926 0.19444444 0.51851852 0.87037037 1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 190.], [0.05743243 0.19932432 0.48310811 0.85810811 0.98310811 1.        ])
# 3
# Cdf([150. 170.], [0.25 1.  ])
# 3
# Cdf([140. 150. 160. 170. 180. 190.], [0.00497512 0.17412935 0.45273632 0.85074627 0.9800995  1.        ])
# 3
# Cdf([120. 150. 160. 170. 180. 190.], [0.00555556 0.19444444 0.41111111 0.88333333 0.99444444 1.        ])
# 3
# Cdf([130. 140. 150. 160. 170. 180. 190. 200.], [4.20521447e-04 4.62573591e-03 9.29352397e-02 3.49032801e-01
#  7.73338940e-01 9.75609756e-01 9.99158957e-01 1.00000000e+00])
# 3
# Cdf([160. 170.], [0.5 1. ])
# 3
# Cdf([120. 130. 140. 150. 160. 170. 180. 190.], [0.00561798 0.01123596 0.02247191 0.26966292 0.55617978 0.8988764
#  0.97752809 1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 190.], [0.00411523 0.16460905 0.38683128 0.81481481 0.97942387 1.        ])
# 3
# Cdf([150. 160. 170.], [0.72727273 0.81818182 1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 190.], [0.01333333 0.19111111 0.47555556 0.81777778 0.96888889 1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 190.], [0.04694836 0.1971831  0.54460094 0.87793427 0.99061033 1.        ])
# 3
# Cdf([170. 180.], [0.5 1. ])
# 3
# Cdf([140. 150. 160. 170. 180. 190. 200.], [0.00357027 0.11814346 0.41804609 0.78481013 0.96429731 0.99870172
#  1.        ])
# 3
# Cdf([150. 160. 170. 180.], [0.23170732 0.48780488 0.86585366 1.        ])
# 3
# Cdf([160.], [1.])
# 3
# Cdf([140. 150. 160. 170. 180. 190.], [0.00384615 0.18461538 0.46153846 0.81923077 0.95       1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 190.], [0.00833333 0.16666667 0.46666667 0.80833333 0.91666667 1.        ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.18518519 0.5        0.82716049 0.98148148 1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 190. 200.], [0.00478796 0.08344733 0.30232558 0.72298222 0.95417237 0.99931601
#  1.        ])
# 3
# Cdf([150. 160. 170. 180. 190. 200.], [0.14482759 0.51724138 0.77931034 0.96551724 0.99310345 1.        ])
# 3
# Cdf([150. 160.], [0.71428571 1.        ])
# 3
# Cdf([120. 150. 160. 170. 180. 190.], [0.02816901 0.12676056 0.44366197 0.87323944 0.97887324 1.        ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.13819095 0.48743719 0.82160804 0.97487437 1.        ])
# 3
# Cdf([150. 160. 170.], [0.42857143 0.71428571 1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 190.], [0.01041667 0.09375    0.44791667 0.79166667 0.96875    1.        ])
# 3
# Cdf([100. 120. 140. 150. 160. 170. 180. 190. 200. 210.], [2.12765957e-04 4.25531915e-04 6.17021277e-03 1.22765957e-01
#  4.00851064e-01 7.49574468e-01 9.52553191e-01 9.98297872e-01
#  9.99787234e-01 1.00000000e+00])
# 3
# Cdf([170. 180.], [0.5 1. ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.18390805 0.4137931  0.77011494 0.97701149 1.        ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.10416667 0.28472222 0.70833333 0.94444444 1.        ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.11724138 0.35862069 0.69655172 0.95862069 1.        ])
# 3
# Cdf([100. 150. 160. 170. 180. 190. 210.], [0.00584795 0.1754386  0.44444444 0.8245614  0.94736842 0.99415205
#  1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 190. 200.], [9.94035785e-04 5.46719682e-02 2.17693837e-01 6.22266402e-01
#  9.30417495e-01 9.94035785e-01 1.00000000e+00])
# 3
# Cdf([140. 150. 160. 170. 180. 190.], [0.00653595 0.08496732 0.47712418 0.86928105 0.97385621 1.        ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.06306306 0.30630631 0.68468468 0.96396396 1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 190.], [0.01652893 0.1322314  0.32231405 0.7231405  0.94628099 1.        ])
# 3
# Cdf([120. 150. 160. 170. 180. 190.], [0.00840336 0.08403361 0.3697479  0.78151261 0.97478992 1.        ])
# 3
# Cdf([180. 190.], [0.5 1. ])
# 3
# Cdf([130. 140. 150. 160. 170. 180. 190. 200. 210.], [4.89715965e-04 2.93829579e-03 6.66013712e-02 2.66895201e-01
#  6.59157689e-01 9.37806072e-01 9.95592556e-01 9.99510284e-01
#  1.00000000e+00])
# 3
# Cdf([140. 150. 160. 170. 180. 190.], [0.02380952 0.27380952 0.46428571 0.80952381 0.97619048 1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 190.], [0.00851064 0.0893617  0.34893617 0.74893617 0.96170213 1.        ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.13084112 0.27102804 0.65420561 0.93457944 1.        ])
# 3
# Cdf([170.], [1.])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.16176471 0.42647059 0.82352941 0.91911765 1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 190. 200. 210.], [0.00329761 0.07666941 0.26133553 0.63643858 0.89859852 0.99505359
#  0.9991756  1.        ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.21495327 0.47663551 0.73831776 0.94392523 1.        ])
# 3
# Cdf([160. 170. 190.], [0.25  0.625 1.   ])
# 3
# Cdf([140. 150. 160. 170. 180. 190. 200.], [0.01515152 0.10606061 0.43181818 0.71969697 0.93181818 0.96969697
#  1.        ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.1        0.37368421 0.67894737 0.95789474 1.        ])
# 3
# Cdf([160. 170.], [0.5 1. ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.06060606 0.33333333 0.81818182 0.95454545 1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 190. 200.], [8.74508089e-04 7.03979012e-02 3.11324880e-01 6.65500656e-01
#  9.19108002e-01 9.97813730e-01 1.00000000e+00])
# 3
# Cdf([160. 170. 180.], [0.14285714 0.71428571 1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 190.], [0.01388889 0.09722222 0.38888889 0.73611111 0.95833333 1.        ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.12371134 0.3814433  0.62886598 0.94845361 1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 190.], [0.01219512 0.13414634 0.40243902 0.7195122  0.92682927 1.        ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.03030303 0.45454545 0.8030303  0.93939394 1.        ])
# 3
# Cdf([170. 190.], [0.5 1. ])
# 3
# Cdf([140. 150. 160. 170. 180. 190. 200. 210.], [0.004004   0.05505506 0.21921922 0.63163163 0.91691692 0.995996
#  0.998999   1.        ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.11428571 0.42857143 0.8        0.92857143 1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 190.], [0.01470588 0.17647059 0.33823529 0.67647059 0.94117647 1.        ])
# 3
# Cdf([160. 190.], [0.5 1. ])
# 3
# Cdf([150. 160. 170. 180. 190. 200.], [0.04210526 0.34736842 0.72631579 0.90526316 0.98947368 1.        ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.175 0.4   0.775 0.925 1.   ])
# 3
# Cdf([130. 140. 150. 160. 170. 180. 190. 200.], [6.07533414e-04 1.82260024e-03 7.47266100e-02 3.15309842e-01
#  6.76184690e-01 9.31956258e-01 9.96354800e-01 1.00000000e+00])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.13888889 0.33333333 0.58333333 0.97222222 1.        ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.1  0.41 0.72 0.91 1.  ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.1   0.575 0.75  0.925 1.   ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.11538462 0.46153846 0.78846154 0.98076923 1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 190. 200.], [0.00319489 0.0543131  0.21565495 0.57028754 0.87220447 0.99041534
#  1.        ])
# 3
# Cdf([190.], [1.])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.13333333 0.44444444 0.75555556 0.88888889 1.        ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.08064516 0.38709677 0.70967742 0.9516129  1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 190.], [0.03846154 0.09615385 0.24038462 0.68269231 0.85576923 1.        ])
# 3
# Cdf([150. 160. 170. 180.], [0.12903226 0.41935484 0.77419355 1.        ])
# 3
# Cdf([130. 140. 150. 160. 170. 180. 190. 200.], [6.42673522e-04 3.21336761e-03 6.81233933e-02 2.64781491e-01
#  6.31105398e-01 9.01670951e-01 9.97429306e-01 1.00000000e+00])
# 3
# Cdf([150. 160. 170. 180.], [0.11428571 0.45714286 0.77142857 1.        ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.17105263 0.42105263 0.69736842 0.90789474 1.        ])
# 3
# Cdf([160.], [1.])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.13333333 0.46666667 0.75555556 0.97777778 1.        ])
# 3
# Cdf([150. 160. 170. 180.], [0.19230769 0.5        0.84615385 1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 190. 200.], [0.00452489 0.06108597 0.22624434 0.62217195 0.88461538 0.98868778
#  1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 190.], [0.01492537 0.10447761 0.3880597  0.65671642 0.88059701 1.        ])
# 3
# Cdf([160.], [1.])
# 3
# Cdf([140. 150. 160. 170. 180. 190.], [0.02040816 0.12244898 0.40816327 0.67346939 0.83673469 1.        ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.05747126 0.34482759 0.67816092 0.94252874 1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 190.], [0.0625  0.375   0.53125 0.84375 0.9375  1.     ])
# 3
# Cdf([130. 140. 150. 160. 170. 180. 190. 200.], [6.43086817e-04 5.14469453e-03 5.65916399e-02 2.99035370e-01
#  6.25080386e-01 8.98392283e-01 9.93569132e-01 1.00000000e+00])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.05263158 0.36842105 0.57894737 0.94736842 1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 190. 200.], [0.015625 0.109375 0.4375   0.734375 0.84375  0.96875  1.      ])
# 3
# Cdf([160. 170. 180. 190.], [0.07407407 0.62962963 0.96296296 1.        ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.02857143 0.45714286 0.88571429 0.97142857 1.        ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.04819277 0.16465863 0.53815261 0.85542169 1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 190.], [0.16129032 0.19354839 0.38709677 0.83870968 0.96774194 1.        ])
# 3
# Cdf([150. 160. 170. 180. 190. 200.], [0.04166667 0.66666667 0.875      0.91666667 0.95833333 1.        ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.09615385 0.28846154 0.63461538 0.80769231 1.        ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.20833333 0.41666667 0.54166667 0.66666667 1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 190. 200.], [0.00358423 0.04181601 0.24850657 0.53524492 0.87455197 0.99522103
#  1.        ])
# 3
# Cdf([160. 170. 180. 190.], [0.125  0.625  0.9375 1.    ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.20454545 0.43181818 0.63636364 0.88636364 1.        ])
# 3
# Cdf([160. 170. 180. 190.], [0.26666667 0.66666667 0.93333333 1.        ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.04545455 0.31818182 0.59090909 0.90909091 1.        ])
# 3
# Cdf([160.], [1.])
# 3
# Cdf([150. 160. 170. 180. 190. 200.], [0.04780876 0.16733068 0.52589641 0.84860558 0.99203187 1.        ])
# 3
# Cdf([150. 160. 170. 180.], [0.2 0.5 0.6 1. ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.03703704 0.18518519 0.7037037  0.96296296 1.        ])
# 3
# Cdf([150. 160. 170. 180. 190. 200.], [0.03333333 0.36666667 0.73333333 0.93333333 0.96666667 1.        ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.23076923 0.46153846 0.61538462 0.92307692 1.        ])
# 3
# Cdf([150. 160. 170. 180. 190. 200.], [0.03518519 0.24259259 0.50925926 0.86481481 0.99074074 1.        ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.0625 0.25   0.3125 0.6875 1.    ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.13333333 0.4        0.56666667 0.73333333 1.        ])
# 3
# Cdf([150. 160. 170.], [0.1 0.7 1. ])
# 3
# Cdf([160. 170. 180. 190.], [0.47058824 0.76470588 0.94117647 1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 190. 200.], [0.00369004 0.03690037 0.19188192 0.5498155  0.81180812 0.99261993
#  1.        ])
# 3
# Cdf([160. 170. 180. 190.], [0.47619048 0.66666667 0.85714286 1.        ])
# 3
# Cdf([150. 160. 170. 180.], [0.2173913  0.30434783 0.52173913 1.        ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.11111111 0.38888889 0.88888889 0.94444444 1.        ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.07142857 0.5        0.71428571 0.78571429 1.        ])
# 3
# Cdf([150. 160. 170. 180. 190. 200.], [0.03238095 0.28       0.54857143 0.84190476 0.99619048 1.        ])
# 3
# Cdf([170. 180. 190.], [0.45454545 0.81818182 1.        ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.06666667 0.2        0.46666667 0.93333333 1.        ])
# 3
# Cdf([160. 170. 180.], [0.55555556 0.72222222 1.        ])
# 3
# Cdf([140. 150. 160. 170. 180.], [0.30769231 0.38461538 0.76923077 0.92307692 1.        ])
# 3
# Cdf([150. 160. 170. 180. 190. 200.], [0.05952381 0.22619048 0.47619048 0.83333333 0.9702381  1.        ])
# 3
# Cdf([140. 150. 160. 170. 180. 200.], [0.04 0.24 0.36 0.76 0.96 1.  ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.04347826 0.56521739 0.69565217 0.73913043 1.        ])
# 3
# Cdf([150. 160. 170. 180.], [0.13333333 0.26666667 0.6        1.        ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.2  0.45 0.65 0.95 1.  ])
# 3
# Cdf([150. 160. 170. 180. 190. 200.], [0.03396226 0.22641509 0.53207547 0.82641509 0.96226415 1.        ])
# 3
# Cdf([150. 160.], [0.33333333 1.        ])
# 3
# Cdf([160. 170. 180. 190.], [0.5625 0.625  0.875  1.    ])
# 3
# Cdf([150. 160. 170. 180.], [0.2 0.4 0.9 1. ])
# 3
# Cdf([150. 160.], [0.5 1. ])
# 3
# Cdf([150. 160. 170. 180. 190. 200.], [0.03 0.1  0.49 0.8  0.98 1.  ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.08 0.16 0.56 0.92 1.  ])
# 3
# Cdf([160. 170. 180. 190. 200.], [0.13333333 0.53333333 0.73333333 0.93333333 1.        ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.05882353 0.35294118 0.47058824 0.88235294 1.        ])
# 3
# Cdf([160. 170. 180. 190.], [0.1 0.3 0.6 1. ])
# 3
# Cdf([150. 160. 170. 180. 190. 200. 210.], [0.04642166 0.26112186 0.57446809 0.84912959 0.99032882 0.99806576
#  1.        ])
# 3
# Cdf([160.], [1.])
# 3
# Cdf([160. 170. 180.], [0.25  0.625 1.   ])
# 3
# Cdf([150. 160. 170. 190.], [0.5        0.66666667 0.83333333 1.        ])
# 3
# Cdf([150. 170. 180.], [0.25 0.75 1.  ])
# 3
# Cdf([160. 170. 180. 190.], [0.29411765 0.62745098 0.92156863 1.        ])
# 3
# Cdf([160. 170. 180.], [0.42857143 0.71428571 1.        ])
# 3
# Cdf([160. 170. 180.], [0.14285714 0.28571429 1.        ])
# 3
# Cdf([160. 170. 180. 190.], [0.16666667 0.33333333 0.83333333 1.        ])
# 3
# Cdf([170. 180.], [0.75 1.  ])
# 3
# Cdf([150. 160. 170. 180. 190. 200.], [0.01010101 0.16161616 0.42424242 0.74747475 0.98989899 1.        ])
# 3
# Cdf([150. 160. 170.], [0.33333333 0.66666667 1.        ])
# 3
# Cdf([170. 180. 190.], [0.46153846 0.76923077 1.        ])
# 3
# Cdf([150. 160. 170.], [0.375 0.625 1.   ])
# 3
# Cdf([160. 170. 180.], [0.7 0.9 1. ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.05084746 0.27118644 0.6440678  0.93220339 1.        ])
# 3
# Cdf([160. 170. 190.], [0.44444444 0.88888889 1.        ])
# 3
# Cdf([170. 180. 190.], [0.33333333 0.66666667 1.        ])
# 3
# Cdf([160. 170. 180.], [0.42857143 0.57142857 1.        ])
# 3
# Cdf([160. 170. 180.], [0.11111111 0.44444444 1.        ])
# 3
# Cdf([150. 160. 170. 180. 190. 200.], [0.04938272 0.2345679  0.51851852 0.79012346 0.99382716 1.        ])
# 3
# Cdf([160. 170. 180. 200.], [0.5        0.66666667 0.83333333 1.        ])
# 3
# Cdf([160.], [1.])
# 3
# Cdf([150. 160. 170. 180.], [0.06666667 0.13333333 0.93333333 1.        ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.08333333 0.20833333 0.45833333 0.95833333 1.        ])
# 3
# Cdf([160. 170. 180.], [0.2 0.5 1. ])
# 3
# Cdf([190.], [1.])
# 3
# Cdf([150. 170. 180.], [0.63636364 0.72727273 1.        ])
# 3
# Cdf([150. 160. 170. 180. 190. 200.], [0.01123596 0.15730337 0.41573034 0.79775281 0.97752809 1.        ])
# 3
# Cdf([150. 160.], [0.66666667 1.        ])
# 3
# Cdf([160.], [1.])
# 3
# Cdf([150. 170.], [0.5 1. ])
# 3
# Cdf([], [])
# 3
# Cdf([150. 170. 190.], [0.16666667 0.66666667 1.        ])
# 3
# Cdf([160. 170.], [0.66666667 1.        ])
# 3
# Cdf([160. 170. 180. 190.], [0.22580645 0.35483871 0.67741935 1.        ])
# 3
# Cdf([160. 170.], [0.33333333 1.        ])
# 3
# Cdf([170. 190.], [0.2 1. ])
# 3
# Cdf([150. 160.], [0.5 1. ])
# 3
# Cdf([160.], [1.])
# 3
# Cdf([150. 160. 170. 180. 190. 200.], [0.09230769 0.16923077 0.56923077 0.8        0.98461538 1.        ])
# 3
# Cdf([160. 170. 180.], [0.5        0.66666667 1.        ])
# 3
# Cdf([160. 180.], [0.2 1. ])
# 3
# Cdf([180.], [1.])
# 3
# Cdf([160. 170. 180. 190.], [0.07692308 0.46153846 0.92307692 1.        ])
# 3
# Cdf([170. 200.], [0.8 1. ])
# 3
# Cdf([170.], [1.])
# 3
# Cdf([160.], [1.])
# 3
# Cdf([160. 170. 180. 190.], [0.27272727 0.54545455 0.90909091 1.        ])
# 3
# Cdf([140.], [1.])
# 3
# Cdf([130. 150. 160. 170. 180. 190. 200.], [0.00900901 0.01801802 0.1981982  0.45045045 0.81081081 0.99099099
#  1.        ])
# 3
# Cdf([190.], [1.])
# 3
# Cdf([180.], [1.])
# 3
# Cdf([170. 180. 190.], [0.33333333 0.91666667 1.        ])
# 3
# Cdf([150. 170.], [0.5 1. ])
# 3
# Cdf([150. 160. 170. 180. 190.], [0.07317073 0.24390244 0.3902439  0.75609756 1.        ])
# 3
# Cdf([200.], [1.])
# 3
# Cdf([120. 160.], [0.6 1. ])
# 3
# Cdf([160. 190.], [0.5 1. ])
# 3
# Cdf([180.], [1.])
# 3
# Cdf([150. 170. 180. 190.], [0.33333333 0.5        0.66666667 1.        ])
# 3
# Cdf([160.], [1.])
# 3
# Cdf([150.], [1.])
# 3
# Cdf([160.], [1.])
# 3
# Cdf([190.], [1.])
# 3
# Cdf([160. 170. 180. 190.], [0.32 0.56 0.88 1.  ])
# 3
# Cdf([170. 180. 200.], [0.33333333 0.66666667 1.        ])
# 3
# Cdf([160. 190.], [0.33333333 1.        ])
# 3
# Cdf([160. 170. 180. 190. 200.], [0.09090909 0.18181818 0.77272727 0.95454545 1.        ])
# 3
# Cdf([160.], [1.])
# 3
# Cdf([150. 160. 170. 180. 190. 200.], [0.07407407 0.14814815 0.25925926 0.66666667 0.96296296 1.        ])
# 3
# Cdf([], [])
# 3
# Cdf([180.], [1.])
# 3
# Cdf([190.], [1.])
# 3
# Cdf([170.], [1.])
# 3
# Cdf([170. 180.], [0.25 1.  ])
# 3
# Cdf([170. 180.], [0.90909091 1.        ])
# 3
# Cdf([160. 170. 180. 190.], [0.25 0.5  0.75 1.  ])
# 3
# Cdf([140.], [1.])
# 3
# Cdf([180.], [1.])
# 3
# Cdf([160.], [1.])
# 3
# Cdf([170. 180.], [0.33333333 1.        ])
# 3
# Cdf([170.], [1.])
# 3
# Cdf([150. 170.], [0.5 1. ])
# 3
# Cdf([150. 160. 170. 180. 190. 200.], [0.0625     0.3125     0.52083333 0.72916667 0.95833333 1.        ])
# 3
# Cdf([180.], [1.])
# 3
# Cdf([160. 190.], [0.5 1. ])
# 3
# Cdf([190.], [1.])
# 3
# Cdf([160. 170.], [0.66666667 1.        ])
# 3
# Cdf([170.], [1.])
# 3
# Cdf([170. 180.], [0.5 1. ])
# 3
# Cdf([150.], [1.])
# 3
# Cdf([140.], [1.])
# 3
# Cdf([170.], [1.])
# 3
# Cdf([160. 170. 180. 190.], [0.2 0.4 0.8 1. ])
# 3
# Cdf([200.], [1.])
# 3
# Cdf([170.], [1.])
# 3
# Cdf([180. 210.], [0.5 1. ])
# 3
# Cdf([180. 200.], [0.66666667 1.        ])
# 3
# Cdf([170.], [1.])
# 3
# Cdf([150. 170.], [0.25 1.  ])
# 3
# Cdf([160.], [1.])
# 3
# Cdf([160. 180.], [0.33333333 1.        ])
# 3
# Cdf([160.], [1.])
# 3
# Cdf([160.], [1.])
# 3
# Cdf([180.], [1.])
# 3
# Cdf([150. 160. 170. 180. 190. 200.], [0.125 0.25  0.5   0.625 0.875 1.   ])
# 3
# Cdf([170.], [1.])
# 3
# Cdf([170.], [1.])
# 3
# Cdf([180.], [1.])
# 3
# Cdf([160. 180. 190.], [0.33333333 0.66666667 1.        ])
# 3
# Cdf([180.], [1.])
# 3
# Cdf([160.], [1.])
# 3
# Cdf([160.], [1.])
# 3
# Cdf([180.], [1.])
# 3
# Cdf([150. 160.], [0.5 1. ])
# 3
# Cdf([180.], [1.])
# 3
# Cdf([160.], [1.])
# 3
# Cdf([180.], [1.])
# 3
# Cdf([160. 180. 190.], [0.5  0.75 1.  ])
# 3
# Cdf([190.], [1.])
# 3
# Cdf([180.], [1.])
# 3
# Cdf([150. 160. 200.], [0.33333333 0.66666667 1.        ])
# 3
# Cdf([150.], [1.])
# 3
# Cdf([150.], [1.])
# 3
# Cdf([200.], [1.])
# 3
# Cdf([180.], [1.])
# 3
# Cdf([180.], [1.])
# 3
# Cdf([170. 180.], [0.33333333 1.        ])
# 3
# Cdf([150.], [1.])
# 3
# Cdf([170.], [1.])
# 3
# Cdf([150. 170. 190.], [0.5        0.83333333 1.        ])
# 3
# Cdf([], [])

# %%
xs = grouped.groups.keys()

# %%
res
# Out:
# [array([170., 160., 160.]),
#  array([160., 140., 140.]),
#  array([170., 150., 120.]),
#  array([160., 150., 150.]),
#  array([170., 150., 150.]),
#  array([150., 140., 140.]),
#  array([180., 150., 140.]),
#  array([160., 150., 140.]),
#  array([150., 150., 140.]),
#  array([170., 140., 130.]),
#  array([160., 150., 140.]),
#  array([160., 150., 140.]),
#  array([150., 150., 130.]),
#  array([160., 150., 140.]),
#  array([160., 150., 140.]),
#  array([170., 150., 150.]),
#  array([160., 150., 140.]),
#  array([180., 150., 140.]),
#  array([170., 150., 140.]),
#  array([160., 150., 140.]),
#  array([160., 150., 140.]),
#  array([160., 150., 140.]),
#  array([160., 150., 140.]),
#  array([160., 150., 150.]),
#  array([160., 160., 140.]),
#  array([160., 150., 140.]),
#  array([170., 150., 140.]),
#  array([160., 150., 140.]),
#  array([170., 150., 140.]),
#  array([170., 150., 150.]),
#  array([160., 150., 140.]),
#  array([160., 150., 140.]),
#  array([160., 150., 140.]),
#  array([160., 150., 140.]),
#  array([160., 150., 140.]),
#  array([170., 150., 140.]),
#  array([160., 150., 140.]),
#  array([160., 160., 150.]),
#  array([170., 150., 140.]),
#  array([170., 150., 140.]),
#  array([170., 150., 140.]),
#  array([160., 150., 140.]),
#  array([170., 150., 140.]),
#  array([160., 150., 140.]),
#  array([170., 150., 150.]),
#  array([160., 150., 140.]),
#  array([170., 160., 140.]),
#  array([160., 150., 150.]),
#  array([170., 150., 150.]),
#  array([160., 150., 140.]),
#  array([160., 150., 110.]),
#  array([170., 150., 140.]),
#  array([160., 150., 140.]),
#  array([160., 160., 140.]),
#  array([170., 160., 150.]),
#  array([160., 150., 140.]),
#  array([170., 160., 150.]),
#  array([170., 160., 150.]),
#  array([190., 170., 160.]),
#  array([170., 160., 140.]),
#  array([170., 150., 150.]),
#  array([170., 160., 150.]),
#  array([170., 170., 160.]),
#  array([180., 150., 150.]),
#  array([170., 160., 140.]),
#  array([170., 160., 130.]),
#  array([170., 160., 140.]),
#  array([170., 160., 140.]),
#  array([170., 170., 150.]),
#  array([170., 160., 150.]),
#  array([170., 150., 150.]),
#  array([170., 160., 150.]),
#  array([170., 160., 150.]),
#  array([170., 160., 150.]),
#  array([180., 160., 150.]),
#  array([170., 160., 140.]),
#  array([170., 160., 150.]),
#  array([180., 160., 150.]),
#  array([180., 160., 110.]),
#  array([170., 160., 150.]),
#  array([170., 160., 150.]),
#  array([180., 170., 140.]),
#  array([170., 160., 150.]),
#  array([170., 160., 150.]),
#  array([170., 160., 160.]),
#  array([170., 160., 150.]),
#  array([170., 160., 150.]),
#  array([170., 170., 160.]),
#  array([170., 160., 150.]),
#  array([170., 150., 140.]),
#  array([160., 160., 150.]),
#  array([170., 160., 150.]),
#  array([170., 160., 150.]),
#  array([170., 160., 150.]),
#  array([170., 160., 160.]),
#  array([170., 160., 140.]),
#  array([170., 160., 150.]),
#  array([190., 160., 150.]),
#  array([180., 160., 150.]),
#  array([170., 160., 150.]),
#  array([170., 170., 160.]),
#  array([170., 160., 150.]),
#  array([170., 160., 150.]),
#  array([170., 160., 160.]),
#  array([180., 160., 150.]),
#  array([180., 160., 150.]),
#  array([170., 160., 150.]),
#  array([180., 160., 150.]),
#  array([170., 160., 150.]),
#  array([190., 170., 150.]),
#  array([180., 160., 150.]),
#  array([180., 160., 150.]),
#  array([170., 160., 140.]),
#  array([170., 160., 150.]),
#  array([180., 160., 150.]),
#  array([190., 170., 160.]),
#  array([180., 160., 150.]),
#  array([180., 160., 150.]),
#  array([170., 170., 150.]),
#  array([180., 160., 150.]),
#  array([180., 160., 150.]),
#  array([180., 170., 150.]),
#  array([180., 160., 150.]),
#  array([180., 160., 150.]),
#  array([180., 160., 150.]),
#  array([180., 160., 160.]),
#  array([180., 170., 150.]),
#  array([180., 170., 140.]),
#  array([180., 170., 160.]),
#  array([180., 160., 150.]),
#  array([180., 160., 150.]),
#  array([180., 160., 150.]),
#  array([180., 170., 150.]),
#  array([180., 160., 160.]),
#  array([180., 160., 150.]),
#  array([180., 170., 140.]),
#  array([170., 170., 150.]),
#  array([180., 170., 150.]),
#  array([180., 170., 150.]),
#  array([180., 170., 150.]),
#  array([170., 160., 160.]),
#  array([180., 160., 150.]),
#  array([180., 170., 150.]),
#  array([170., 150., 150.]),
#  array([180., 170., 150.]),
#  array([180., 160., 150.]),
#  array([180., 170., 170.]),
#  array([180., 170., 150.]),
#  array([180., 170., 150.]),
#  array([180., 170., 150.]),
#  array([190., 170., 150.]),
#  array([180., 160., 150.]),
#  array([180., 170., 150.]),
#  array([180., 160., 150.]),
#  array([160., 150., 150.]),
#  array([180., 170., 150.]),
#  array([180., 170., 150.]),
#  array([170., 160., 150.]),
#  array([180., 170., 150.]),
#  array([180., 170., 150.]),
#  array([180., 170., 170.]),
#  array([180., 170., 150.]),
#  array([190., 170., 150.]),
#  array([180., 170., 150.]),
#  array([190., 170., 150.]),
#  array([190., 170., 150.]),
#  array([180., 170., 150.]),
#  array([180., 170., 150.]),
#  array([190., 170., 150.]),
#  array([180., 170., 150.]),
#  array([190., 180., 180.]),
#  array([190., 170., 150.]),
#  array([180., 170., 150.]),
#  array([180., 170., 150.]),
#  array([190., 170., 150.]),
#  array([190., 170., 150.]),
#  array([190., 170., 150.]),
#  array([190., 170., 150.]),
#  array([190., 170., 160.]),
#  array([190., 170., 150.]),
#  array([180., 170., 150.]),
#  array([170., 160., 160.]),
#  array([180., 170., 150.]),
#  array([190., 170., 150.]),
#  array([180., 170., 160.]),
#  array([180., 170., 150.]),
#  array([190., 170., 150.]),
#  array([190., 170., 150.]),
#  array([190., 170., 160.]),
#  array([190., 170., 170.]),
#  array([190., 170., 150.]),
#  array([190., 170., 150.]),
#  array([190., 170., 150.]),
#  array([190., 160., 160.]),
#  array([190., 170., 160.]),
#  array([190., 170., 150.]),
#  array([190., 170., 150.]),
#  array([180., 170., 150.]),
#  array([190., 170., 150.]),
#  array([190., 160., 150.]),
#  array([180., 170., 150.]),
#  array([190., 170., 150.]),
#  array([190., 170., 150.]),
#  array([180., 170., 150.]),
#  array([190., 170., 150.]),
#  array([180., 170., 150.]),
#  array([190., 170., 150.]),
#  array([180., 170., 150.]),
#  array([190., 170., 150.]),
#  array([180., 170., 150.]),
#  array([180., 160., 150.]),
#  array([190., 170., 150.]),
#  array([190., 170., 150.]),
#  array([190., 170., 150.]),
#  array([190., 170., 150.]),
#  array([190., 160., 140.]),
#  array([190., 170., 150.]),
#  array([190., 170., 150.]),
#  array([190., 170., 150.]),
#  array([180., 170., 160.]),
#  array([180., 170., 160.]),
#  array([190., 170., 160.]),
#  array([180., 170., 140.]),
#  array([190., 160., 160.]),
#  array([190., 170., 150.]),
#  array([190., 170., 150.]),
#  array([190., 170., 160.]),
#  array([190., 170., 160.]),
#  array([190., 170., 150.]),
#  array([190., 170., 160.]),
#  array([190., 170., 160.]),
#  array([190., 170., 160.]),
#  array([180., 160., 150.]),
#  array([180., 170., 160.]),
#  array([190., 170., 160.]),
#  array([190., 170., 150.]),
#  array([190., 170., 160.]),
#  array([190., 180., 150.]),
#  array([190., 170., 150.]),
#  array([170., 160., 150.]),
#  array([190., 170., 160.]),
#  array([190., 170., 160.]),
#  array([190., 170., 160.]),
#  array([180., 170., 150.]),
#  array([190., 170., 150.]),
#  array([190., 160., 150.]),
#  array([190., 170., 160.]),
#  array([190., 180., 170.]),
#  array([190., 180., 150.]),
#  array([180., 160., 160.]),
#  array([180., 160., 140.]),
#  array([190., 180., 150.]),
#  array([180., 170., 150.]),
#  array([190., 160., 160.]),
#  array([180., 170., 150.]),
#  array([180., 170., 150.]),
#  array([190., 170., 160.]),
#  array([160., 160., 150.]),
#  array([190., 160., 160.]),
#  array([180., 170., 150.]),
#  array([160., 150., 150.]),
#  array([190., 180., 160.]),
#  array([190., 170., 150.]),
#  array([200., 170., 160.]),
#  array([190., 180., 150.]),
#  array([190., 180., 160.]),
#  array([190., 170., 160.]),
#  array([180., 170., 160.]),
#  array([190., 150., 150.]),
#  array([180., 170., 150.]),
#  array([190., 170., 160.]),
#  array([180., 170., 160.]),
#  array([180., 180., 160.]),
#  array([190., 180., 160.]),
#  array([180., 170., 170.]),
#  array([190., 180., 160.]),
#  array([170., 160., 150.]),
#  array([190., 180., 170.]),
#  array([170., 160., 150.]),
#  array([180., 160., 160.]),
#  array([190., 170., 150.]),
#  array([190., 170., 160.]),
#  array([190., 180., 170.]),
#  array([180., 170., 160.]),
#  array([180., 180., 160.]),
#  array([190., 170., 160.]),
#  array([200., 160., 160.]),
#  array([180., 170., 150.]),
#  array([180., 180., 150.]),
#  array([180., 170., 160.]),
#  array([180., 150., 150.]),
#  array([190., 180., 160.]),
#  array([160., 150., 150.]),
#  array([170., 150., 150.]),
#  array([190., 170., 150.]),
#  array([170., 160., 160.]),
#  array([190., 180., 160.]),
#  array([170., 170., 160.]),
#  array([190., 190., 170.]),
#  array([160., 150., 150.]),
#  array([190., 170., 150.]),
#  array([180., 160., 160.]),
#  array([180., 180., 160.]),
#  array([190., 180., 160.]),
#  array([200., 170., 170.]),
#  array([190., 170., 160.]),
#  array([190., 180., 160.]),
#  array([190., 180., 170.]),
#  array([170., 150., 150.]),
#  array([190., 180., 150.]),
#  array([160., 120., 120.]),
#  array([190., 160., 160.]),
#  array([190., 170., 150.]),
#  array([190., 170., 160.]),
#  array([200., 180., 170.]),
#  array([190., 190., 160.]),
#  array([190., 180., 160.]),
#  array([190., 180., 150.]),
#  array([180., 180., 170.]),
#  array([180., 170., 170.]),
#  array([190., 170., 160.]),
#  array([180., 180., 170.]),
#  array([170., 150., 150.]),
#  array([190., 170., 150.]),
#  array([190., 160., 160.]),
#  array([170., 160., 160.]),
#  array([180., 170., 170.]),
#  array([190., 180., 160.]),
#  array([210., 180., 180.]),
#  array([200., 180., 180.]),
#  array([170., 170., 150.]),
#  array([180., 180., 160.]),
#  array([200., 170., 150.]),
#  array([190., 180., 160.]),
#  array([160., 150., 150.]),
#  array([190., 160., 160.]),
#  array([200., 160., 150.]),
#  array([180., 180., 170.]),
#  array([190., 150., 150.])]

# %%
np.transpose(res)
# Out:
# array([[170., 160., 170., ..., 200., 180., 190.],
#        [160., 140., 150., ..., 160., 180., 150.],
#        [160., 140., 120., ..., 150., 170., 150.]])

# %%
rows = np.transpose(res)

width = [1,2,1]

t=0
for i, qs in enumerate(rows):
    #while (t < 1):
     #   print(list(xs)[0:339])
      #  print(qs)
       # t = 2
    plt.plot(list(xs)[0:339], qs, label=ps[i], linewidth=width[i], color='C4')
    
decorate(xlabel='Weight (kg)',
         ylabel='Height (cm)')

# %% [markdown]
# I had a ton of trouble getting this last section to work. I know the graph above is nearly impossible to read, but I would like to ask someone about how to make it work more cleanly.

# %% [markdown]
# ## Vegetables
#
# **Exercise:** The variable `_VEGESU1` contains the self-reported number of serving of vegetables each respondent eats per day.  Explore relationships between this variable and the others variables in the dataset, and design visualizations that show any relationship you find as clearly as possible.

# %%
veg = brfss['_VEGESU1']

# %%
list(brfss.columns.values)
# Out:
# ['SEX',
#  'HTM4',
#  'WTKG3',
#  'INCOME2',
#  '_LLCPWT',
#  '_AGEG5YR',
#  '_VEGESU1',
#  '_HTMG10',
#  'AGE']

# %%
sex = brfss['SEX']

# %%
plt.plot(sex, veg, 'o', alpha=0.2)
plt.xlabel('Sex')
plt.ylabel('Veggies Consumed')
# Out:
# Text(0, 0.5, 'Veggies Consumed')

# %% [markdown]
# Well, that wasn't very useful.

# %%
cdf = thinkstats2.Cdf(sex)
thinkplot.Cdf(cdf)
# Out:
# {'xscale': 'linear', 'yscale': 'linear'}

# %% [markdown]
# Again, pretty useless honestly. I suppose I should have seen coming that it would be hard when there are only two answers for sex.

# %%
income = brfss['INCOME2']

# %%
plt.plot(income, veg, 'o', alpha=0.1)

# %% [markdown]
# Doesn't feel like jittering will help much, but one can try.

# %%
income_jittered = income + np.random.normal(0, 0.25, size=len(income))
plt.plot(income_jittered, veg, 'o', alpha=0.1)
plt.xlabel('Income')
plt.ylabel('Veggies Consumed')
# Out:
# Text(0, 0.5, 'Veggies Consumed')

# %% [markdown]
# Looks like there's a little bit of a relationship, although its a little hard to tell.

# %%
sub2 = brfss.dropna(subset=['INCOME2', '_VEGESU1'])
xs = sub2['INCOME2']
ys = sub2['_VEGESU1']

res = linregress(xs, ys)
res
# Out:
# LinregressResult(slope=0.06988048092105006, intercept=1.5287786243363113, rvalue=0.11967005884864092, pvalue=1.378503916249654e-238, stderr=0.0021109763563323305)

# %%
plt.plot(income_jittered, veg, 'o', alpha=0.1)
plt.xlabel('Income')
plt.ylabel('Veggies Consumed')

fx = np.array([xs.min(), xs.max()])
fy = res.intercept + res.slope * fx
plt.plot(fx, fy, '-', alpha=1)

# %% [markdown]
# There's a slope of 0.06 there, so nothing too substantial, but income does perhaps have a slight impact on the amount of vegetables you consume.

# %%
height = brfss['_HTMG10']
cdf = thinkstats2.Cdf(height)
cdf2 = thinkstats2.Cdf(veg)
thinkplot.Cdf(cdf)
thinkplot.Config(ylabel='Cdf',xlabel='height (cm)')

# %%
thinkplot.Cdf(cdf2)
thinkplot.Config(ylabel='Cdf',xlabel='Veggies consumed daily')

# %% [markdown]
# People eat a lot less vegetables than you would hope. I actually looked up how much a serving was, it says half a cup. That doesn't seem like much to me.

# %%
plt.plot(height, veg, 'o', alpha=0.1, markersize=3)
plt.ylabel('Vegetable servings')
plt.xlabel('Height (cm)')
# Out:
# Text(0.5, 0, 'Height (cm)')

# %% [markdown]
# I'll use the jittered height from earlier now.

# %%
plt.plot(height_jitter, veg, 'o', alpha=0.1, markersize=3)
plt.ylabel('Vegetable servings')
plt.xlabel('Height (cm)')
# Out:
# Text(0.5, 0, 'Height (cm)')

# %% [markdown]
# It kind of looks like the people who eat the most vegetables are those around 160-180 cm, given the height of the distribution above the main blob of data. However, given that 175 cm is the average height of Americans, this may just be because there are more people sampled in the average height group than other groups.

# %% [markdown]
# Let's try weight.

# %%
plt.plot(weight, veg, 'o', alpha=0.1, markersize=3)
plt.ylabel('Vegetable servings')
plt.xlabel('Weight (kg)')
# Out:
# Text(0.5, 0, 'Weight (kg)')

# %%
plt.plot(weight_jitter, veg, 'o', alpha=0.1, markersize=3)
plt.ylabel('Vegetable servings')
plt.xlabel('Weight (kg)')
# Out:
# Text(0.5, 0, 'Weight (kg)')

# %%
sub2 = brfss.dropna(subset=['WTKG3', '_VEGESU1'])
xs = sub2['WTKG3']
ys = sub2['_VEGESU1']

res = linregress(xs, ys)
res
# Out:
# LinregressResult(slope=-0.0026726589934251716, intercept=2.1420188498853996, rvalue=-0.04335602618034541, pvalue=2.7376126834691902e-36, stderr=0.00021236092449150435)

# %%
plt.plot(weight_jitter, veg, 'o', alpha=0.1)
plt.xlabel('Weight (kg)')
plt.ylabel('Veggies Consumed')

fx = np.array([xs.min(), xs.max()])
fy = res.intercept + res.slope * fx
plt.plot(fx, fy, '-', alpha=1)

# %% [markdown]
# Perhaps those who are heavier eat fewer vegetables, but again, it's hard to say.

# %% [markdown]
# ## Correlation
#
# One way to compute correlations is the Pandas method `corr`, which returns a correlation matrix.

# %%
subset = brfss[['HTM4', 'WTKG3', 'AGE']]
subset.corr()
# Out:
#            HTM4     WTKG3       AGE
# HTM4   1.000000  0.474203 -0.093684
# WTKG3  0.474203  1.000000  0.021641
# AGE   -0.093684  0.021641  1.000000

# %% [markdown]
# **Exercise:** Compute a correlation matrix for age, income, and vegetable servings.

# %%
subset = brfss[['AGE', 'INCOME2', '_VEGESU1']]
subset.corr()
# Out:
#                AGE   INCOME2  _VEGESU1
# AGE       1.000000 -0.015158 -0.009834
# INCOME2  -0.015158  1.000000  0.119670
# _VEGESU1 -0.009834  0.119670  1.000000

# %% [markdown]
# ## Correlation calibration

# %% [markdown]
# To calibrate your sense of correlation, let's look at scatter plots for fake data with different values of `rho`.
#
# The following function generates random normally-distributed data with approximately the given coefficient of correlation.

# %%
def gen_corr(rho):
    means = [0, 0]
    covs = [[1, rho], [rho, 1]]
    m = np.random.multivariate_normal(means, covs, 100)
    return np.transpose(m)

# %% [markdown]
# This function makes a scatter plot and shows the actual value of `rho`.

# %%
def plot_scatter(rho, seed=1):
    np.random.seed(seed)
    xs, ys = gen_corr(rho)
    rho = np.corrcoef(xs, ys)[0][1]

    plt.plot(xs, ys, 'o', alpha=0.5)
    plt.xlabel('x')
    plt.ylabel('y')
    ax = plt.gca()
    label_rho(ax, rho)
    
    return xs, ys

# %%
def label_rho(ax, rho):
    label = 'ρ = %0.2f' % rho
    plt.text(0.05, 0.95, label, 
             horizontalalignment='left', 
             verticalalignment='top', 
             transform=ax.transAxes,
             fontsize=12)

# %% [markdown]
# The following plots show what scatter plots look like with different values of `rho`.

# %%
res = []
xs, ys = plot_scatter(0, seed=18)
res.append((xs, ys))

# %%
xs, ys = plot_scatter(0.25, seed=18)
res.append((xs, ys))

# %%
xs, ys = plot_scatter(0.5, seed=18)
res.append((xs, ys))

# %%
xs, ys = plot_scatter(0.75, seed=18)
res.append((xs, ys))

# %%
xs, ys = plot_scatter(0.95, seed=18)
res.append((xs, ys))

# %% [markdown]
# Here are all the plots side-by-side for comparison.

# %%
fig, axes = plt.subplots(ncols=5, sharey=True, figsize=(15,3)) 

for ax, (xs, ys) in zip(axes, res):
    ax.plot(xs, ys, 'o', alpha=0.5)
    rho = np.corrcoef(xs, ys)[0][1]
    label_rho(ax, rho)

# %% [markdown]
# ## Nonlinear relationships
#
# Here an example that generates fake data with a nonlinear relationship.

# %%
np.random.seed(18)
xs = np.linspace(-1, 1)
ys = xs**2 + np.random.normal(0, 0.05, len(xs))

plt.plot(xs, ys, 'o', alpha=0.5)
plt.xlabel('x')
plt.ylabel('y');

# %% [markdown]
# This relationship is quite strong, in the sense that we can make a much better guess about `y` if we know `x` than if we don't.
#
# But if we compute correlations, they don't show the relationship.

# %%
df = pd.DataFrame(dict(xs=xs, ys=ys))
df.corr(method='pearson')
# Out:
#           xs        ys
# xs  1.000000 -0.011014
# ys -0.011014  1.000000

# %%
df.corr(method='spearman')
# Out:
#           xs        ys
# xs  1.000000 -0.005234
# ys -0.005234  1.000000

# %%
df.corr(method='kendall')
# Out:
#           xs        ys
# xs  1.000000  0.004082
# ys  0.004082  1.000000

# %% [markdown]
# ## Correlation strength
#
# Here are two fake datasets showing hypothetical relationships between weight and age.

# %%
np.random.seed(18)
xs = np.linspace(20, 50)
ys1 = 75 + 0.02 * xs + np.random.normal(0, 0.15, len(xs))

plt.plot(xs, ys1, 'o', alpha=0.5)
plt.xlabel('Age in years')
plt.ylabel('Weight in kg')

rho = np.corrcoef(xs, ys1)[0][1]
label_rho(plt.gca(), rho)

# %%
np.random.seed(18)
xs = np.linspace(20, 50)
ys2 = 65 + 0.2 * xs + np.random.normal(0, 3, len(xs))

plt.plot(xs, ys2, 'o', alpha=0.5)
plt.xlabel('Age in years')
plt.ylabel('Weight in kg')

rho = np.corrcoef(xs, ys2)[0][1]
label_rho(plt.gca(), rho)

# %% [markdown]
# Which relationship is stronger?
#
# It depends on what we mean.  Clearly, the first one has a higher coefficient of correlation.  In that world, knowing someone's age would allow you to make a better guess about their weight.
#
# But look more closely at the y-axis in the two plots.  How much weight do people gain per year in each of these hypothetical worlds?

# %%
from scipy.stats import linregress
        
res = linregress(xs, ys1)
res
# Out:
# LinregressResult(slope=0.018821034903244386, intercept=75.08049023710964, rvalue=0.7579660563439402, pvalue=1.8470158725246148e-10, stderr=0.002337849260560818)

# %%
res = linregress(xs, ys2)
res
# Out:
# LinregressResult(slope=0.17642069806488855, intercept=66.60980474219305, rvalue=0.47827769765763173, pvalue=0.0004430600283776241, stderr=0.04675698521121631)

# %% [markdown]
# In fact, the slope for the second data set is almost 10 times higher.

# %% [markdown]
# The following figures show the same data again, this time with the line of best fit and the estimated slope.

# %%
def label_slope(ax, slope):
    label = 'm = %0.3f' % slope
    plt.text(0.05, 0.95, label, 
             horizontalalignment='left', 
             verticalalignment='top', 
             transform=ax.transAxes,
             fontsize=12)

# %%
res = linregress(xs, ys1)
fx = np.array([xs.min(), xs.max()])
fy = res.intercept + res.slope * fx

plt.plot(xs, ys1, 'o', alpha=0.5)
plt.plot(fx, fy, '-', alpha=0.5)

plt.xlabel('Age in years')
plt.ylabel('Weight in kg')
label_slope(plt.gca(), res.slope)

plt.gca().get_ylim()
# Out:
# (75.35118093219263, 76.29172584257574)

# %%
res = linregress(xs, ys2)
fx = np.array([xs.min(), xs.max()])
fy = res.intercept + res.slope * fx

plt.plot(xs, ys2, 'o', alpha=0.5)
plt.plot(fx, fy, '-', alpha=0.5)

plt.xlabel('Age in years')
plt.ylabel('Weight in kg')
label_slope(plt.gca(), res.slope)

plt.gca().get_ylim()
# Out:
# (66.62157782752605, 81.25696583110674)

# %% [markdown]
# The difference is not obvious from looking at the figure; you have to look carefully at the y-axis labels and the estimated slope.
#
# And you have to interpret the slope in context.  In the first case, people gain about 0.019 kg per year, which works out to less than half a pound per decade.  In the second case, they gain almost 4 pounds per decade.
#
# But remember that in the first case, the coefficient of correlation is substantially higher.
#
# **Exercise:** So, in which case is the relationship "stronger"?  Write a sentence or two below to summarize your thoughts.

# %% [markdown]
# I suppose it depends on exactly what you mean when you say "stronger", but I would say the relationship is stronger in the second case. I think this is really why we take classes like data science, because it is important to consider the results in context. We could either present the findings from these two cases simply in terms of the coefficients of correlation, in which case one would assume that age and weight as highly (compared to the other one) correlated. If we consider the two in context, we see that while age and weight may not be that highly correlated, people weights do tend to increase as they get older by a small amount each year.
